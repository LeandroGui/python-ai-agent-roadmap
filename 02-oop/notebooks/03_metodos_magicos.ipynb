# %% [markdown]
# # ✨ Cortex Nivel 2: Métodos Mágicos (Dunder Methods)
#
# Python nos permite definir cómo se comportan nuestros objetos ante operaciones nativas mediante métodos que empiezan y terminan con doble guion bajo (`__`).
#
# ## Los más importantes para Agentes:
# 1.  `__str__` y `__repr__`: Definen cómo se "ve" el objeto cuando hacemos `print(agente)`. Fundamental para logs y debugging.
# 2.  `__call__`: Permite usar el objeto como si fuera una función: `agente("hola")`. Esto simplifica mucho la sintaxis en frameworks como LangChain.
# 3.  `__len__`: Permite usar `len(agente)` (por ejemplo, para saber cuántos elementos tiene en memoria).

# %%
class SmartAgent:
    def __init__(self, name):
        self.name = name
        self.knowledge_base = []

    # 1. Representación legible (String)
    def __str__(self):
        return f"🤖 AGENTE [{self.name}] - Items en memoria: {len(self.knowledge_base)}"

    # 2. Invocación directa (Call)
    def __call__(self, input_text):
        """Permite ejecutar: agente('texto')"""
        print(f"Procesando: {input_text}...")
        self.knowledge_base.append(input_text)
        return "Procesado."

    # 3. Longitud
    def __len__(self):
        return len(self.knowledge_base)

# --- Uso ---
my_agent = SmartAgent("Cortex_V2")

# Gracias a __call__, usamos el objeto como función
my_agent("Aprender Python")
my_agent("Aprender OOP")

# Gracias a __str__, el print es bonito
print(my_agent)

# Gracias a __len__
print(f"Conocimientos totales: {len(my_agent)}")
# Out:
# Procesando: Aprender Python...
# Procesando: Aprender OOP...
# 🤖 AGENTE [Cortex_V2] - Items en memoria: 2
# Conocimientos totales: 2
